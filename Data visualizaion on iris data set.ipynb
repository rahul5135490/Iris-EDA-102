# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.distplot(df["sepal_length"])
plt.show()

# %%
sns.distplot(df["sepal_width"],color="red")
plt.show()

# %%
sns.distplot(df["petal_length"])
plt.show()

# %%
sns.distplot(df["petal_width"],color="green")
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.countplot(x="species",data=df)
plt.show()

# %%
df["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
sns.barplot(x="sepal_length",y="species",data=df)
plt.show()

# %%
sns.barplot(x="species",y="sepal_length",data=df)
plt.show()

# %%
sns.relplot(x="sepal_length",y="sepal_width",data=df)
plt.show()

# %%
sns.relplot(x="petal_length",y="petal_width",data=df)
plt.show()

# %%
sns.relplot(x="sepal_length",y="petal_width",data=df)
plt.show()

# %%
sns.catplot(x="sepal_length",y="species",data=df)
plt.show()

# %%
sns.catplot(x="petal_length",y="species",data=df)
plt.show()

# %%
sns.catplot(x="petal_width",y="species",data=df)
plt.show()

# %%
sns.catplot(x="sepal_width",y="species",data=df)
plt.show()

# %%
sns.catplot(x="sepal_width",y="species",kind="swarm",data=df)
plt.show()

# %%
sns.catplot(x="sepal_width",y="species",kind="box",data=df)
plt.show()

# %%
sns.catplot(x="species",y="sepal_length",kind="box",data=df)
plt.show()

# %%
sns.catplot(x="species",y="petal_length",kind="box",data=df)
plt.show()

# %%
sns.catplot(x="species",y="sepal_width",kind="box",data=df)
plt.show()

# %%
sns.catplot(x="species",y="petal_width",kind="box",data=df)
plt.show()

# %%
sns.catplot(x="species",y="sepal_length",kind="violin",data=df)
plt.show()

# %%
sns.catplot(x="species",y="petal_length",kind="violin",data=df)
plt.show()

# %%
sns.catplot(x="species",y="sepal_width",kind="violin",data=df)
plt.show()

# %%
sns.catplot(x="species",y="petal_width",kind="violin",data=df)
plt.show()

# %%
sns.jointplot(x="sepal_length",y="petal_width",data=df)
plt.show()

# %%
sns.jointplot(x="sepal_length",y="sepal_width",data=df)
plt.show()

# %%
sns.jointplot(x="petal_length",y="petal_width",data=df)
plt.show()

# %%
sns.jointplot(x="sepal_width",y="petal_length",data=df)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.distplot(df["sepal_length"],color="yellow")
plt.grid(color = 'green', linestyle = '--', linewidth = 1.5)
plt.show()

# %%
sns.distplot(df["petal_length"],color="purple")
plt.grid(color = 'green', linestyle = '--', linewidth = 1.5)
plt.show()
